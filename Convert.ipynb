# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
import random as r, string as s, shutil, os, time

import os, sys, time, threading, multiprocessing, random as r

inputDirName = 'inputDirectory'
outputDirName = 'outputDirectory'


try:
    # Delete input directory and then create it
    shutil.rmtree("./%s/"%(outputDirName))
    os.mkdir(outputDirName)
except:
    # Create the input directory
    os.mkdir(outputDirName)

# %%
def task(fileName):
    inFileName ="./%s/%s"%(inputDirName,fileName)
    outFileName ="./%s/%s"%(outputDirName,fileName)

    inFile = open(inFileName)
    outFile = open(outFileName,"w")

    for line in inFile:
      outFile.write(line.upper())
    inFile.close()
    outFile.close()
    return None

# %%
startTime = time.time()

numberOfThreads = 5
totalFiles = 20

activeThreads = threading.activeCount()

# Main Program - Run Multiple Threads
print("Program Started....")

for i in range(totalFiles):
    fileName = "test%d.txt"%(i+1)
    cmd = fileName
    t = threading.Thread(target=task , args=(cmd,))
    t.start()

    print ("Creating file %s"%(fileName))

    while True:
      if threading.activeCount() - activeThreads + 1 <= numberOfThreads:
        break
      time.sleep(1)



# Waiting to finish all Threads
while True:
    if threading.activeCount() == activeThreads:
        break
    else:
        print ("    Thread still running (left %d)..."%(threading.activeCount() - activeThreads))
        time.sleep(1)

print(" All Thread ends")

print("Program Finished")
print("Total Time %f sec" % (round( time.time() - startTime,4)))
# Out:
# <ipython-input-8-4d41a960665a>:6: DeprecationWarning: activeCount() is deprecated, use active_count() instead
#   activeThreads = threading.activeCount()
# <ipython-input-8-4d41a960665a>:20: DeprecationWarning: activeCount() is deprecated, use active_count() instead
#   if threading.activeCount() - activeThreads + 1 <= numberOfThreads:
# Exception in thread Thread-10 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test1.txt'
# Exception in thread Thread-11 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test2.txt'
# Exception in thread Thread-13 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-12 (task)    self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
# :
# Exception in thread Thread-14 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()    FileNotFoundErrorException in thread Thread-15 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# : [Errno 2] No such file or directory: './inputDirectory/test4.txt'
#
#   File "/usr/lib/python3.10/threading.py", line 953, in run
# self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
# Exception in thread Thread-16 (task)    self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test7.txt'
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test6.txt'
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test5.txt'
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test3.txt'
# Program Started....
# Creating file test1.txt
# Creating file test2.txt
# Creating file test3.txt
# Creating file test4.txt
# Creating file test5.txt
# Creating file test6.txt
# Creating file test7.txt
# Exception in thread Thread-17 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test8.txt'
# Exception in thread Thread-18 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test9.txt'
# Exception in thread Thread-19 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test10.txt'
# Exception in thread Thread-20 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test11.txt'
# Exception in thread Thread-21 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test12.txt'
# Exception in thread Thread-22 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test13.txt'
# Exception in thread Thread-24 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test15.txt'
# Exception in thread Thread-23 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test14.txt'
# Exception in thread Thread-25 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test16.txt'
# Exception in thread Thread-26 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test17.txt'
# Exception in thread Thread-27 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-28 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread <ipython-input-8-4d41a960665a>:28: DeprecationWarning: activeCount() is deprecated, use active_count() instead
#   if threading.activeCount() == activeThreads:
# <ipython-input-8-4d41a960665a>:31: DeprecationWarning: activeCount() is deprecated, use active_count() instead
#   print ("    Thread still running (left %d)..."%(threading.activeCount() - activeThreads))
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test18.txt'
# Thread-29 (task):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test19.txt'
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-711bd4fc349b>", line 5, in task
# FileNotFoundError: [Errno 2] No such file or directory: './inputDirectory/test20.txt'
# Creating file test8.txt
# Creating file test9.txt
# Creating file test10.txt
# Creating file test11.txt
# Creating file test12.txt
# Creating file test13.txt
# Creating file test14.txt
# Creating file test15.txt
# Creating file test16.txt
# Creating file test17.txt
# Creating file test18.txt
# Creating file test19.txt
# Creating file test20.txt
#     Thread still running (left 4)...
#  All Thread ends
# Program Finished
# Total Time 2.116600 sec
